# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Paul\\sb\\Untitled Folder'

# %%
filenames = os.listdir('.\\raw_data')
filenames
# Out:
# ['nba_betting_money_line.csv',
#  'nba_betting_spread.csv',
#  'nba_betting_totals.csv',
#  'nba_games_all.csv',
#  'nba_players_all.csv',
#  'nba_players_game_stats.csv',
#  'nba_teams_all.csv']

# %%
dataframes = [pd.read_csv('.\\raw_data\\' + f) for f in filenames]
dataframes
# Out:
# [         game_id        book_name  book_id     team_id   a_team_id  price1  \
#  0       41100314  Pinnacle Sports      238  1610612759  1610612760   165.0
#  1       41100314           5Dimes       19  1610612759  1610612760   165.0
#  2       41100314        Bookmaker       93  1610612759  1610612760   160.0
#  3       41100314        BetOnline     1096  1610612759  1610612760   165.0
#  4       41100314           Bovada   999996  1610612759  1610612760   155.0
#  ...          ...              ...      ...         ...         ...     ...
#  125281  41700215         Heritage      169  1610612755  1610612738   105.0
#  125282  41700215        Intertops      180  1610612755  1610612738   100.0
#  125283  41700215         YouWager      139  1610612755  1610612738   105.0
#  125284  41700215          JustBet     1275  1610612755  1610612738   100.0
#  125285  41700215    Sportsbetting   999991  1610612755  1610612738   105.0
#
#          price2
#  0       -183.0
#  1       -175.0
# ...

# %%
dataframes[0]
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  price1  \
# 0       41100314  Pinnacle Sports      238  1610612759  1610612760   165.0
# 1       41100314           5Dimes       19  1610612759  1610612760   165.0
# 2       41100314        Bookmaker       93  1610612759  1610612760   160.0
# 3       41100314        BetOnline     1096  1610612759  1610612760   165.0
# 4       41100314           Bovada   999996  1610612759  1610612760   155.0
# ...          ...              ...      ...         ...         ...     ...
# 125281  41700215         Heritage      169  1610612755  1610612738   105.0
# 125282  41700215        Intertops      180  1610612755  1610612738   100.0
# 125283  41700215         YouWager      139  1610612755  1610612738   105.0
# 125284  41700215          JustBet     1275  1610612755  1610612738   100.0
# 125285  41700215    Sportsbetting   999991  1610612755  1610612738   105.0
#
#         price2
# 0       -183.0
# 1       -175.0
# 2       -190.0
# ...

# %%
dataframes[1]
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  spread1  \
# 0       21000358  Pinnacle Sports      238  1610612749  1610612742      7.5
# 1       21000358           5Dimes       19  1610612749  1610612742      7.5
# 2       21000358        Bookmaker       93  1610612749  1610612742      7.5
# 3       21000358        BetOnline     1096  1610612749  1610612742      7.5
# 4       21000358           Bovada   999996  1610612749  1610612742      8.0
# ...          ...              ...      ...         ...         ...      ...
# 131685  21501153        BetOnline     1096  1610612738  1610612747     -9.0
# 131686  21501153           Bovada   999996  1610612738  1610612747     -9.5
# 131687  21501153         Heritage      169  1610612738  1610612747     -9.5
# 131688  21501153        Intertops      180  1610612738  1610612747     -9.5
# 131689  21501153         YouWager      139  1610612738  1610612747     -9.0
#
#         spread2  price1  price2
# ...

# %%
dataframes[2]
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  total1  \
# 0       21100131  Pinnacle Sports      238  1610612740  1610612743   192.0
# 1       21100131           5Dimes       19  1610612740  1610612743   192.0
# 2       21100131        Bookmaker       93  1610612740  1610612743   192.0
# 3       21100131        BetOnline     1096  1610612740  1610612743   191.5
# 4       21100131           Bovada   999996  1610612740  1610612743   192.0
# ...          ...              ...      ...         ...         ...     ...
# 131381  41700215         Heritage      169  1610612755  1610612738   204.5
# 131382  41700215        Intertops      180  1610612755  1610612738   205.0
# 131383  41700215         YouWager      139  1610612755  1610612738   204.5
# 131384  41700215          JustBet     1275  1610612755  1610612738   204.0
# 131385  41700215    Sportsbetting   999991  1610612755  1610612738   204.5
#
#         total2  price1  price2
# 0        192.0  -105.0  -105.0
# ...

# %%
dataframes[3]
# Out:
#          game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0       20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 1       20800701  2009-01-31  POR vs. UTA  1610612762       f  L  26.0  22.0
# 2       20800584  2009-01-16  MEM vs. UTA  1610612762       f  W  24.0  16.0
# 3       20800558  2009-01-12    IND @ UTA  1610612762       t  W  23.0  15.0
# 4       20800440  2008-12-27  HOU vs. UTA  1610612762       f  L  18.0  14.0
# ...          ...         ...          ...         ...     ... ..   ...   ...
# 125619  20801131  2009-04-03    MIN @ UTA  1610612762       t  L  46.0  30.0
# 125620  20801058  2009-03-24    HOU @ UTA  1610612762       t  W  44.0  26.0
# 125621  20801029  2009-03-20  OKC vs. UTA  1610612762       f  W  43.0  26.0
# 125622  20800839  2009-02-23    ATL @ UTA  1610612762       t  W  34.0  23.0
# 125623  20800810  2009-02-19    BOS @ UTA  1610612762       t  W  32.0  23.0
#
# ...

# %%
dataframes[4]
# Out:
#       person_id display_last_comma_first   display_first_last rosterstatus  \
# 0         76001          Abdelnaby, Alaa       Alaa Abdelnaby            f
# 1         76002         Abdul-Aziz, Zaid      Zaid Abdul-Aziz            f
# 2         76003     Abdul-Jabbar, Kareem  Kareem Abdul-Jabbar            f
# 3            51      Abdul-Rauf, Mahmoud   Mahmoud Abdul-Rauf            f
# 4          1505       Abdul-Wahad, Tariq    Tariq Abdul-Wahad            f
# ...         ...                      ...                  ...          ...
# 4880        953         Wright, Lorenzen      Lorenzen Wright            f
# 4881       1007           Wright, Luther        Luther Wright            f
# 4882        412          Wright, Sharone       Sharone Wright            f
# 4883     203100             Wroten, Tony          Tony Wroten            f
# 4884      78627             Wynder, A.J.          A.J. Wynder            f
#
# ...

# %%
#dataframes[5].info()
dataframes[5]
# Out:
#          season_id  player_id             player_name     team_id  \
# 0            21950      77036  Bear, The Body Hoffman  1610610024
# 1            21950      78447            Paul Walther  1610610030
# 2            21950      77675              Ken Murray  1610610024
# 3            21950      77347               Bob Lavoy  1610610030
# 4            21950      77132           Arnie Johnson  1610612758
# ...            ...        ...                     ...         ...
# 1268206      32017     202331             Paul George  1610616833
# 1268207      32017     203078            Bradley Beal  1610616833
# 1268208      32017     201942           DeMar DeRozan  1610616834
# 1268209      32017     201143              Al Horford  1610616834
# 1268210      32017     203081          Damian Lillard  1610616834
#
#         team_abbreviation               team_name   game_id   game_date  \
# 0                     BAL       Baltimore Bullets  25000009  1950-11-04
# ...

# %%
dataframes[6].info()
dataframes[6]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 5 columns):
# league_id       69 non-null int64
# team_id         69 non-null int64
# min_year        45 non-null float64
# max_year        45 non-null float64
# abbreviation    30 non-null object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.8+ KB
#     league_id     team_id  min_year  max_year abbreviation
# 0           0  1610612737    1949.0    2018.0          ATL
# 1           0  1610612738    1946.0    2018.0          BOS
# 2           0  1610612739    1970.0    2018.0          CLE
# 3           0  1610612740    2002.0    2018.0          NOP
# 4           0  1610612741    1966.0    2018.0          CHI
# 5           0  1610612742    1980.0    2018.0          DAL
# 6           0  1610612743    1976.0    2018.0          DEN
# 7           0  1610612744    1946.0    2018.0          GSW
# 8           0  1610612745    1967.0    2018.0          HOU
# ...

# %%
#XXXXXXXXXXXb/c appears to be joining on index
#df10 = dataframes[0].join(dataframes[1], lsuffix='_money_line', rsuffix='_spread')
#df10

# %%
dataframes[0] = dataframes[0].rename(columns={'price1':'m_price1', 'price2': 'm_price2'})
dataframes[0]
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  m_price1  \
# 0       41100314  Pinnacle Sports      238  1610612759  1610612760     165.0
# 1       41100314           5Dimes       19  1610612759  1610612760     165.0
# 2       41100314        Bookmaker       93  1610612759  1610612760     160.0
# 3       41100314        BetOnline     1096  1610612759  1610612760     165.0
# 4       41100314           Bovada   999996  1610612759  1610612760     155.0
# ...          ...              ...      ...         ...         ...       ...
# 125281  41700215         Heritage      169  1610612755  1610612738     105.0
# 125282  41700215        Intertops      180  1610612755  1610612738     100.0
# 125283  41700215         YouWager      139  1610612755  1610612738     105.0
# 125284  41700215          JustBet     1275  1610612755  1610612738     100.0
# 125285  41700215    Sportsbetting   999991  1610612755  1610612738     105.0
#
#         m_price2
# 0         -183.0
# ...

# %%
dataframes[1] = dataframes[1].rename(columns={'price1':'s_price1', 'price2':'s_price2'})
dataframes[1]
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  spread1  \
# 0       21000358  Pinnacle Sports      238  1610612749  1610612742      7.5
# 1       21000358           5Dimes       19  1610612749  1610612742      7.5
# 2       21000358        Bookmaker       93  1610612749  1610612742      7.5
# 3       21000358        BetOnline     1096  1610612749  1610612742      7.5
# 4       21000358           Bovada   999996  1610612749  1610612742      8.0
# ...          ...              ...      ...         ...         ...      ...
# 131685  21501153        BetOnline     1096  1610612738  1610612747     -9.0
# 131686  21501153           Bovada   999996  1610612738  1610612747     -9.5
# 131687  21501153         Heritage      169  1610612738  1610612747     -9.5
# 131688  21501153        Intertops      180  1610612738  1610612747     -9.5
# 131689  21501153         YouWager      139  1610612738  1610612747     -9.0
#
#         spread2  s_price1  s_price2
# ...

# %%
dataframes[2] = dataframes[2].rename(columns={'price1':'t_price1', 'price2':'t_price2'})
dataframes[2]
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  total1  \
# 0       21100131  Pinnacle Sports      238  1610612740  1610612743   192.0
# 1       21100131           5Dimes       19  1610612740  1610612743   192.0
# 2       21100131        Bookmaker       93  1610612740  1610612743   192.0
# 3       21100131        BetOnline     1096  1610612740  1610612743   191.5
# 4       21100131           Bovada   999996  1610612740  1610612743   192.0
# ...          ...              ...      ...         ...         ...     ...
# 131381  41700215         Heritage      169  1610612755  1610612738   204.5
# 131382  41700215        Intertops      180  1610612755  1610612738   205.0
# 131383  41700215         YouWager      139  1610612755  1610612738   204.5
# 131384  41700215          JustBet     1275  1610612755  1610612738   204.0
# 131385  41700215    Sportsbetting   999991  1610612755  1610612738   204.5
#
#         total2  t_price1  t_price2
# ...

# %%
df = pd.merge(dataframes[0], dataframes[1], how='outer', on=['game_id', 'book_name', 'book_id', 'team_id', 'a_team_id'])
df
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  m_price1  \
# 0       41100314  Pinnacle Sports      238  1610612759  1610612760     165.0
# 1       41100314           5Dimes       19  1610612759  1610612760     165.0
# 2       41100314        Bookmaker       93  1610612759  1610612760     160.0
# 3       41100314        BetOnline     1096  1610612759  1610612760     165.0
# 4       41100314           Bovada   999996  1610612759  1610612760     155.0
# ...          ...              ...      ...         ...         ...       ...
# 131774  21501103           Bovada   999996  1610612742  1610612743       NaN
# 131775  21501111           Bovada   999996  1610612745  1610612739       NaN
# 131776  21501126           Bovada   999996  1610612746  1610612760       NaN
# 131777  21501150           Bovada   999996  1610612741  1610612749       NaN
# 131778  21501152           Bovada   999996  1610612757  1610612744       NaN
#
# ...

# %%
#131690 for [1]

# %%
len(dataframes[0])
# Out:
# 125286

# %%
len(dataframes[1])
# Out:
# 131690

# %%
#=====================>>>>>>>>>> 131779 -

# %%
131779 - 131690
# Out:
# 89

# %% [markdown]
# <font color='red'> clean up or delete the the 89 rows?????<font>

# %%
df = pd.merge(df, dataframes[2], how='outer', on=['game_id', 'book_name', 'book_id', 'team_id', 'a_team_id'])
df
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  m_price1  \
# 0       41100314  Pinnacle Sports      238  1610612759  1610612760     165.0
# 1       41100314           5Dimes       19  1610612759  1610612760     165.0
# 2       41100314        Bookmaker       93  1610612759  1610612760     160.0
# 3       41100314        BetOnline     1096  1610612759  1610612760     165.0
# 4       41100314           Bovada   999996  1610612759  1610612760     155.0
# ...          ...              ...      ...         ...         ...       ...
# 131850  20800193          JustBet     1275  1610612738  1610612761       NaN
# 131851  20800193    Sportsbetting   999991  1610612738  1610612761       NaN
# 131852  21000939        Bookmaker       93  1610612738  1610612749       NaN
# 131853  21000965        Bookmaker       93  1610612752  1610612742       NaN
# 131854  21000994        Bookmaker       93  1610612746  1610612763       NaN
#
# ...

# %%
131855 - 131779
# Out:
# 76

# %%
#=======================>>>>>>>>>>>

# %%
#highest row count is dataframes[1] at 131690
#lowest row count is dataframes[0] at 125286
131690 - 125286
# Out:
# 6404

# %%
#total increase in rows
131855 - 131690
# Out:
# 165

# %% [markdown]
# <font color='red'> 165 rows (presenting each game with a particular book) were not in common across all three dataframes???????????<font>

# %% [markdown]
# <font color='red'> what games and books were these????? <font>

# %%
df
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  m_price1  \
# 0       41100314  Pinnacle Sports      238  1610612759  1610612760     165.0
# 1       41100314           5Dimes       19  1610612759  1610612760     165.0
# 2       41100314        Bookmaker       93  1610612759  1610612760     160.0
# 3       41100314        BetOnline     1096  1610612759  1610612760     165.0
# 4       41100314           Bovada   999996  1610612759  1610612760     155.0
# ...          ...              ...      ...         ...         ...       ...
# 131850  20800193          JustBet     1275  1610612738  1610612761       NaN
# 131851  20800193    Sportsbetting   999991  1610612738  1610612761       NaN
# 131852  21000939        Bookmaker       93  1610612738  1610612749       NaN
# 131853  21000965        Bookmaker       93  1610612752  1610612742       NaN
# 131854  21000994        Bookmaker       93  1610612746  1610612763       NaN
#
# ...

# %%
df = pd.merge(df, dataframes[6][['team_id', 'abbreviation']], how='left', on=['team_id'])
df
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  m_price1  \
# 0       41100314  Pinnacle Sports      238  1610612759  1610612760     165.0
# 1       41100314           5Dimes       19  1610612759  1610612760     165.0
# 2       41100314        Bookmaker       93  1610612759  1610612760     160.0
# 3       41100314        BetOnline     1096  1610612759  1610612760     165.0
# 4       41100314           Bovada   999996  1610612759  1610612760     155.0
# ...          ...              ...      ...         ...         ...       ...
# 131850  20800193          JustBet     1275  1610612738  1610612761       NaN
# 131851  20800193    Sportsbetting   999991  1610612738  1610612761       NaN
# 131852  21000939        Bookmaker       93  1610612738  1610612749       NaN
# 131853  21000965        Bookmaker       93  1610612752  1610612742       NaN
# 131854  21000994        Bookmaker       93  1610612746  1610612763       NaN
#
# ...

# %%
#dataframes[6][['team_id', 'abbreviation']]

# %%
df2 = dataframes[6].rename(columns={'team_id': 'a_team_id', 'abbreviation': 'a_abbreviation'})
df2
# Out:
#     league_id   a_team_id  min_year  max_year a_abbreviation
# 0           0  1610612737    1949.0    2018.0            ATL
# 1           0  1610612738    1946.0    2018.0            BOS
# 2           0  1610612739    1970.0    2018.0            CLE
# 3           0  1610612740    2002.0    2018.0            NOP
# 4           0  1610612741    1966.0    2018.0            CHI
# 5           0  1610612742    1980.0    2018.0            DAL
# 6           0  1610612743    1976.0    2018.0            DEN
# 7           0  1610612744    1946.0    2018.0            GSW
# 8           0  1610612745    1967.0    2018.0            HOU
# 9           0  1610612746    1970.0    2018.0            LAC
# 10          0  1610612747    1948.0    2018.0            LAL
# 11          0  1610612748    1988.0    2018.0            MIA
# 12          0  1610612749    1968.0    2018.0            MIL
# 13          0  1610612750    1989.0    2018.0            MIN
# ...

# %%
df = pd.merge(df, df2[['a_team_id', 'a_abbreviation']], how='left', on=['a_team_id'])
df
# Out:
#          game_id        book_name  book_id     team_id   a_team_id  m_price1  \
# 0       41100314  Pinnacle Sports      238  1610612759  1610612760     165.0
# 1       41100314           5Dimes       19  1610612759  1610612760     165.0
# 2       41100314        Bookmaker       93  1610612759  1610612760     160.0
# 3       41100314        BetOnline     1096  1610612759  1610612760     165.0
# 4       41100314           Bovada   999996  1610612759  1610612760     155.0
# ...          ...              ...      ...         ...         ...       ...
# 131850  20800193          JustBet     1275  1610612738  1610612761       NaN
# 131851  20800193    Sportsbetting   999991  1610612738  1610612761       NaN
# 131852  21000939        Bookmaker       93  1610612738  1610612749       NaN
# 131853  21000965        Bookmaker       93  1610612752  1610612742       NaN
# 131854  21000994        Bookmaker       93  1610612746  1610612763       NaN
#
# ...

# %%
dataframes[3][['game_id', 'game_date']]
# Out:
#          game_id   game_date
# 0       20800741  2009-02-06
# 1       20800701  2009-01-31
# 2       20800584  2009-01-16
# 3       20800558  2009-01-12
# 4       20800440  2008-12-27
# ...          ...         ...
# 125619  20801131  2009-04-03
# 125620  20801058  2009-03-24
# 125621  20801029  2009-03-20
# 125622  20800839  2009-02-23
# 125623  20800810  2009-02-19
#
# [125624 rows x 2 columns]

# %%
df = pd.merge(df, dataframes[3][['game_id', 'game_date']], how='left', on=['game_id'])
df.head(100)
# Out:
#      game_id        book_name  book_id     team_id   a_team_id  m_price1  \
# 0   41100314  Pinnacle Sports      238  1610612759  1610612760     165.0
# 1   41100314  Pinnacle Sports      238  1610612759  1610612760     165.0
# 2   41100314           5Dimes       19  1610612759  1610612760     165.0
# 3   41100314           5Dimes       19  1610612759  1610612760     165.0
# 4   41100314        Bookmaker       93  1610612759  1610612760     160.0
# 5   41100314        Bookmaker       93  1610612759  1610612760     160.0
# 6   41100314        BetOnline     1096  1610612759  1610612760     165.0
# 7   41100314        BetOnline     1096  1610612759  1610612760     165.0
# 8   41100314           Bovada   999996  1610612759  1610612760     155.0
# 9   41100314           Bovada   999996  1610612759  1610612760     155.0
# 10  41100314         Heritage      169  1610612759  1610612760     163.0
# 11  41100314         Heritage      169  1610612759  1610612760     163.0
# ...
