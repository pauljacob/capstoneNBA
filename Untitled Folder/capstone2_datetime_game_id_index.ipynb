# %%
#using games_all and index by date and game id

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
df_games = pd.read_csv('C:\\Users\\Paul\\sb\\Untitled Folder\\raw_data\\nba_games_all.csv')
df_games.head()
# Out:
#     game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0  20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 1  20800701  2009-01-31  POR vs. UTA  1610612762       f  L  26.0  22.0
# 2  20800584  2009-01-16  MEM vs. UTA  1610612762       f  W  24.0  16.0
# 3  20800558  2009-01-12    IND @ UTA  1610612762       t  W  23.0  15.0
# 4  20800440  2008-12-27  HOU vs. UTA  1610612762       f  L  18.0  14.0
#
#    w_pct  min   fgm    fga  fg_pct  fg3m  fg3a  fg3_pct   ftm   fta  ft_pct  \
# 0  0.569  240  39.0   74.0   0.527   4.0  13.0    0.308  29.0  37.0     1.0
# 1  0.542  240  37.0   68.0   0.544   5.0  20.0    0.250  29.0  37.0     1.0
# 2  0.600  240  37.0   71.0   0.521   7.0  19.0    0.368  20.0  27.0     1.0
# 3  0.605  240  39.0   85.0   0.459   8.0  18.0    0.444  34.0  37.0     1.0
# 4  0.563  290  49.0  100.0   0.490   5.0  13.0    0.385  12.0  18.0     1.0
#
# ...

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125624 entries, 0 to 125623
# Data columns (total 32 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   game_id      125624 non-null  int64
#  1   game_date    119376 non-null  object
#  2   matchup      125624 non-null  object
#  3   team_id      125624 non-null  int64
#  4   is_home      125624 non-null  object
#  5   wl           125614 non-null  object
#  6   w            41000 non-null   float64
#  7   l            41000 non-null   float64
#  8   w_pct        41000 non-null   float64
#  9   min          125624 non-null  int64
#  10  fgm          125607 non-null  float64
#  11  fga          90894 non-null   float64
#  12  fg_pct       90871 non-null   float64
#  13  fg3m         95248 non-null   float64
#  14  fg3a         84316 non-null   float64
#  15  fg3_pct      80062 non-null   float64
#  16  ftm          125605 non-null  float64
# ...

# %%
df_games['game_id'].unique().shape
# Out:
# (62812,)

# %%
df_games.shape[0] / df_games['game_id'].unique().shape[0]
# Out:
# 2.0

# %%
#side stack visitor and home team

# %%
df_teams = pd.read_csv('C:\\Users\\Paul\\sb\\Untitled Folder\\raw_data\\nba_teams_all.csv')
df_teams.head()
# Out:
#    league_id     team_id  min_year  max_year abbreviation
# 0          0  1610612737    1949.0    2018.0          ATL
# 1          0  1610612738    1946.0    2018.0          BOS
# 2          0  1610612739    1970.0    2018.0          CLE
# 3          0  1610612740    2002.0    2018.0          NOP
# 4          0  1610612741    1966.0    2018.0          CHI

# %%
df_teams.shape
# Out:
# (69, 5)

# %%
df_teams['abbreviation'].unique()
# Out:
# array(['ATL', 'BOS', 'CLE', 'NOP', 'CHI', 'DAL', 'DEN', 'GSW', 'HOU',
#        'LAC', 'LAL', 'MIA', 'MIL', 'MIN', 'BKN', 'NYK', 'ORL', nan, 'IND',
#        'PHI', 'PHX', 'POR', 'SAC', 'SAS', 'OKC', 'TOR', 'UTA', 'MEM',
#        'WAS', 'DET', 'CHA'], dtype=object)

# %%
team_names = df_teams['abbreviation'].unique()
team_names
# Out:
# array(['ATL', 'BOS', 'CLE', 'NOP', 'CHI', 'DAL', 'DEN', 'GSW', 'HOU',
#        'LAC', 'LAL', 'MIA', 'MIL', 'MIN', 'BKN', 'NYK', 'ORL', nan, 'IND',
#        'PHI', 'PHX', 'POR', 'SAC', 'SAS', 'OKC', 'TOR', 'UTA', 'MEM',
#        'WAS', 'DET', 'CHA'], dtype=object)

# %%
df_teams[df_teams['abbreviation'].isnull()].head()
# Out:
#     league_id     team_id  min_year  max_year abbreviation
# 17          0  1610616834       NaN       NaN          NaN
# 18          0  1610616833       NaN       NaN          NaN
# 19          0       12306       NaN       NaN          NaN
# 20          0       12303       NaN       NaN          NaN
# 21          0       12313       NaN       NaN          NaN

# %%
df_teams[df_teams['abbreviation'].isnull()].shape
# Out:
# (39, 5)

# %%
df_teams['team_id'].unique()
# Out:
# array([1610612737, 1610612738, 1610612739, 1610612740, 1610612741,
#        1610612742, 1610612743, 1610612744, 1610612745, 1610612746,
#        1610612747, 1610612748, 1610612749, 1610612750, 1610612751,
#        1610612752, 1610612753, 1610616834, 1610616833,      12306,
#             12303,      12313,      12316,         45,      12308,
#             12304,      12320,      12315,         94,      12321,
#             12324,         93,         41,      12325,      12323,
#             12330,      15015,      15018,      12329,      15016,
#             15017, 1610612754, 1610612755, 1610612756, 1610612757,
#        1610612758, 1610612759, 1610612760, 1610612761, 1610612762,
#        1610612763, 1610612764, 1610612765, 1610612766, 1610610029,
#        1610610025, 1610610034, 1610610036, 1610610024, 1610610031,
#        1610610027, 1610610030, 1610610033, 1610610037, 1610610023,
#        1610610026, 1610610028, 1610610032, 1610610035], dtype=int64)

# %%
df_teams['team_id'].unique().shape
# Out:
# (69,)

# %%
df_games['team_id'].unique().shape
# Out:
# (57,)

# %%
df_games['team_id'].unique()
# Out:
# array([1610612762, 1610612764, 1610612763, 1610612765, 1610612766,
#        1610612760, 1610612761, 1610612753, 1610612751, 1610612754,
#        1610612752, 1610610036, 1610612758, 1610612756, 1610612755,
#        1610612757, 1610612750, 1610612743, 1610612741, 1610612746,
#        1610612747, 1610612745, 1610612748, 1610612749, 1610612759,
#        1610612739, 1610612737, 1610612742, 1610612738, 1610612740,
#        1610612744,      12304,         93,      12308, 1610610030,
#        1610610024, 1610616833,      12303,      12313,      12315,
#             12320,         94, 1610616834,      12325,      15016,
#             15015,      12316,      12323,      12329,      12306,
#                45,      12321,         41,      15018,      15017,
#             12324,      12330], dtype=int64)

# %%
#team id 93??????

# %%
df_games[df_games['team_id'] == 93]
# Out:
#          game_id game_date      matchup  team_id is_home wl    w    l  w_pct  \
# 1022    11000002       NaN  NJN vs. MAC       93       f  L  0.0  1.0    0.0
# 1497    11300046       NaN  MEM vs. MAC       93       f  L  0.0  3.0    0.0
# 1658    11400104       NaN  TOR vs. MAC       93       f  L  0.0  4.0    0.0
# 1849    11500043       NaN  LAL vs. MAC       93       f  L  0.0  2.0    0.0
# 1850    11500024       NaN  MEM vs. MAC       93       f  L  0.0  1.0    0.0
# 21035   11700074       NaN  POR vs. MAC       93       f  L  0.0  3.0    0.0
# 33311   11300020       NaN  DET vs. MAC       93       f  L  0.0  2.0    0.0
# 64651   11300009       NaN  PHX vs. MAC       93       f  L  0.0  1.0    0.0
# 64819   11400075       NaN  SAC vs. MAC       93       f  L  0.0  3.0    0.0
# 64820   11400070       NaN  POR vs. MAC       93       f  L  0.0  2.0    0.0
# 64821   11400054       NaN  WAS vs. MAC       93       f  L  0.0  1.0    0.0
# ...

# %%
df_games['team_id']
# Out:
# 0         1610612762
# 1         1610612762
# 2         1610612762
# 3         1610612762
# 4         1610612762
#              ...
# 125619    1610612762
# 125620    1610612762
# 125621    1610612762
# 125622    1610612762
# 125623    1610612762
# Name: team_id, Length: 125624, dtype: int64

# %%
#what is the progression of teams changing their names???? did some teams get phased out and others not? when was this?

# %%
#df_games['team_id']
df_games['game_date'].notnull().sum()
# Out:
# 119376

# %%
df_games['game_date'].isnull().sum()
# Out:
# 6248

# %%
df_games[df_games['game_date'].isnull()]
# Out:
#          game_id game_date      matchup     team_id is_home wl    w    l  \
# 34      20800023       NaN    ORL @ MEM  1610612763       t  W  1.0  1.0
# 35      10800096       NaN  ORL vs. MEM  1610612763       f  L  2.0  6.0
# 36      10800044       NaN    IND @ MEM  1610612763       t  W  2.0  2.0
# 37      10800009       NaN  HOU vs. MEM  1610612763       f  L  0.0  1.0
# 54      10800084       NaN  PHX vs. CHA  1610612766       f  L  0.0  6.0
# ...          ...       ...          ...         ...     ... ..  ...  ...
# 125570  10800079       NaN    NJN @ BOS  1610612738       t  W  5.0  2.0
# 125571  10800036       NaN    HOU @ BOS  1610612738       t  W  2.0  1.0
# 125572  10800032       NaN    CLE @ BOS  1610612738       t  W  1.0  1.0
# 125617  10800107       NaN    ATL @ DET  1610612765       t  L  6.0  2.0
# 125618  10800025       NaN  WAS vs. DET  1610612765       f  W  3.0  0.0
#
#         w_pct  min   fgm   fga  fg_pct  fg3m  fg3a  fg3_pct   ftm   fta  \
# ...

# %%
df_games_date_clean= df_games[df_games['game_date'].notnull()]
df_games_date_clean
# Out:
#          game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0       20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 1       20800701  2009-01-31  POR vs. UTA  1610612762       f  L  26.0  22.0
# 2       20800584  2009-01-16  MEM vs. UTA  1610612762       f  W  24.0  16.0
# 3       20800558  2009-01-12    IND @ UTA  1610612762       t  W  23.0  15.0
# 4       20800440  2008-12-27  HOU vs. UTA  1610612762       f  L  18.0  14.0
# ...          ...         ...          ...         ...     ... ..   ...   ...
# 125619  20801131  2009-04-03    MIN @ UTA  1610612762       t  L  46.0  30.0
# 125620  20801058  2009-03-24    HOU @ UTA  1610612762       t  W  44.0  26.0
# 125621  20801029  2009-03-20  OKC vs. UTA  1610612762       f  W  43.0  26.0
# 125622  20800839  2009-02-23    ATL @ UTA  1610612762       t  W  34.0  23.0
# 125623  20800810  2009-02-19    BOS @ UTA  1610612762       t  W  32.0  23.0
#
# ...

# %%
df_games_date_clean['game_date'] = pd.to_datetime(df_games_date_clean['game_date'])
df_games_date_clean
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#          game_id  game_date      matchup     team_id is_home wl     w     l  \
# 0       20800741 2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 1       20800701 2009-01-31  POR vs. UTA  1610612762       f  L  26.0  22.0
# 2       20800584 2009-01-16  MEM vs. UTA  1610612762       f  W  24.0  16.0
# 3       20800558 2009-01-12    IND @ UTA  1610612762       t  W  23.0  15.0
# 4       20800440 2008-12-27  HOU vs. UTA  1610612762       f  L  18.0  14.0
# ...          ...        ...          ...         ...     ... ..   ...   ...
# ...

# %%
df_games_date_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119376 entries, 0 to 125623
# Data columns (total 32 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   game_id      119376 non-null  int64
#  1   game_date    119376 non-null  datetime64[ns]
#  2   matchup      119376 non-null  object
#  3   team_id      119376 non-null  int64
#  4   is_home      119376 non-null  object
#  5   wl           119372 non-null  object
#  6   w            37740 non-null   float64
#  7   l            37740 non-null   float64
#  8   w_pct        37740 non-null   float64
#  9   min          119376 non-null  int64
#  10  fgm          119361 non-null  float64
#  11  fga          87130 non-null   float64
#  12  fg_pct       87107 non-null   float64
#  13  fg3m         90988 non-null   float64
#  14  fg3a         80684 non-null   float64
#  15  fg3_pct      76526 non-null   float64
#  16  ftm          119359 non-null  float64
# ...

# %%
df_games_date_clean[['game_id', 'game_date']]
# Out:
#          game_id  game_date
# 0       20800741 2009-02-06
# 1       20800701 2009-01-31
# 2       20800584 2009-01-16
# 3       20800558 2009-01-12
# 4       20800440 2008-12-27
# ...          ...        ...
# 125619  20801131 2009-04-03
# 125620  20801058 2009-03-24
# 125621  20801029 2009-03-20
# 125622  20800839 2009-02-23
# 125623  20800810 2009-02-19
#
# [119376 rows x 2 columns]

# %%
df_games_date_clean.groupby(['game_id', 'game_date']).size().reset_index().rename(columns={0:'count'})
# Out:
#         game_id  game_date  count
# 0      11100001 2011-12-16      2
# 1      11100002 2011-12-16      2
# 2      11100003 2011-12-16      2
# 3      11100004 2011-12-16      2
# 4      11100005 2011-12-17      2
# ...         ...        ...    ...
# 59683  49900084 2000-06-09      2
# 59684  49900085 2000-06-11      2
# 59685  49900086 2000-06-14      2
# 59686  49900087 2000-06-16      2
# 59687  49900088 2000-06-19      2
#
# [59688 rows x 3 columns]

# %%
df_games_date_clean.groupby(['game_id', 'game_date']).size().reset_index().rename(columns={0:'count'})['count'].value_counts()
# Out:
# 2    59688
# Name: count, dtype: int64

# %%
df_games_date_clean.sort_values(by='game_id', inplace=True)
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# <font color='red'> is there a way to check to for game_date play sequentially as the game_id sequence dictates here????</font>

# %%
df_games_date_clean[df_games_date_clean['game_date'].dt.year == 2015]
# Out:
#          game_id  game_date      matchup     team_id is_home wl     w     l  \
# 10728   21400482 2015-01-01  CHI vs. DEN  1610612743       f  L  13.0  20.0
# 10784   21400482 2015-01-01    DEN @ CHI  1610612741       t  W  23.0  10.0
# 33581   21400483 2015-01-01  MIN vs. SAC  1610612758       f  W  14.0  19.0
# 42315   21400483 2015-01-01    SAC @ MIN  1610612750       t  L   5.0  26.0
# 104423  21400484 2015-01-02    CLE @ CHA  1610612766       t  L  10.0  24.0
# ...          ...        ...          ...         ...     ... ..   ...   ...
# 73114   41400404 2015-06-11    GSW @ CLE  1610612739       t  L   2.0   2.0
# 73806   41400405 2015-06-14    CLE @ GSW  1610612744       t  W   3.0   2.0
# 73113   41400405 2015-06-14  GSW vs. CLE  1610612739       f  L   2.0   3.0
# 104206  41400406 2015-06-16    GSW @ CLE  1610612739       t  L   2.0   4.0
# 105019  41400406 2015-06-16  CLE vs. GSW  1610612744       f  W   4.0   2.0
#
# ...

# %%
plt.scatter(df_games_date_clean[df_games_date_clean['game_date'].dt.year == 2017]['game_date'], 
            df_games_date_clean[df_games_date_clean['game_date'].dt.year == 2017]['game_id'])

# %%
df_games_date_clean[df_games_date_clean['season'] == '2014-15']
# Out:
#          game_id  game_date      matchup     team_id is_home wl    w    l  \
# 42389   21400027 2014-11-01    DAL @ NOP  1610612740       t  L  1.0  1.0
# 48577   21400027 2014-11-01  NOP vs. DAL  1610612742       f  W  2.0  1.0
# 42005   21400028 2014-11-01    MEM @ CHA  1610612766       t  L  1.0  1.0
# 33516   21400028 2014-11-01  CHA vs. MEM  1610612763       f  W  3.0  0.0
# 10384   21400029 2014-11-01  ORL vs. TOR  1610612761       f  W  2.0  0.0
# ...          ...        ...          ...         ...     ... ..  ...  ...
# 73114   41400404 2015-06-11    GSW @ CLE  1610612739       t  L  2.0  2.0
# 73806   41400405 2015-06-14    CLE @ GSW  1610612744       t  W  3.0  2.0
# 73113   41400405 2015-06-14  GSW vs. CLE  1610612739       f  L  2.0  3.0
# 104206  41400406 2015-06-16    GSW @ CLE  1610612739       t  L  2.0  4.0
# 105019  41400406 2015-06-16  CLE vs. GSW  1610612744       f  W  4.0  2.0
#
#         w_pct  min   fgm   fga  fg_pct  fg3m  fg3a  fg3_pct   ftm   fta  \
# ...

# %%
plt.scatter(df_games_date_clean[df_games_date_clean['season'] == '2014-15']['game_date'], df_games_date_clean[df_games_date_clean['season'] == '2014-15']['game_id'])

# %% [markdown]
# <font color='red'> shoudl there be some kind of cutting up of the data for playoff's and regular season? and why?</font>

# %% [markdown]
# <font color='red'> why start with the regular season?????</font>

# %%
df_games_date_clean[df_games_date_clean['season'] == '2014-15'][df_games_date_clean['season_type'] == 'Regular Season']
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         game_id  game_date      matchup     team_id is_home wl     w     l  \
# 42389  21400027 2014-11-01    DAL @ NOP  1610612740       t  L   1.0   1.0
# 48577  21400027 2014-11-01  NOP vs. DAL  1610612742       f  W   2.0   1.0
# 42005  21400028 2014-11-01    MEM @ CHA  1610612766       t  L   1.0   1.0
# 33516  21400028 2014-11-01  CHA vs. MEM  1610612763       f  W   3.0   0.0
# 10384  21400029 2014-11-01  ORL vs. TOR  1610612761       f  W   2.0   0.0
# ...         ...        ...          ...         ...     ... ..   ...   ...
# 10301  21401228 2015-04-15  TOR vs. CHA  1610612766       f  L  33.0  49.0
# 73777  21401229 2015-04-15    DEN @ GSW  1610612744       t  W  67.0  15.0
# 73648  21401229 2015-04-15  GSW vs. DEN  1610612743       f  L  30.0  52.0
# ...

# %%
plt.scatter(df_games_date_clean[df_games_date_clean['season'] == '2014-15'][df_games_date_clean['season_type'] == 'Regular Season']['game_date'], df_games_date_clean[df_games_date_clean['season'] == '2014-15'][df_games_date_clean['season_type'] == 'Regular Season']['game_id'])
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
df_games_2014 = df_games_date_clean[df_games_date_clean['season'] == '2014-15'][df_games_date_clean['season_type'] == 'Regular Season']
df_games_2014
# Out:
# C:\Users\Paul\anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#         game_id  game_date      matchup     team_id is_home wl     w     l  \
# 42389  21400027 2014-11-01    DAL @ NOP  1610612740       t  L   1.0   1.0
# 48577  21400027 2014-11-01  NOP vs. DAL  1610612742       f  W   2.0   1.0
# 42005  21400028 2014-11-01    MEM @ CHA  1610612766       t  L   1.0   1.0
# 33516  21400028 2014-11-01  CHA vs. MEM  1610612763       f  W   3.0   0.0
# 10384  21400029 2014-11-01  ORL vs. TOR  1610612761       f  W   2.0   0.0
# ...         ...        ...          ...         ...     ... ..   ...   ...
# 10301  21401228 2015-04-15  TOR vs. CHA  1610612766       f  L  33.0  49.0
# 73777  21401229 2015-04-15    DEN @ GSW  1610612744       t  W  67.0  15.0
# 73648  21401229 2015-04-15  GSW vs. DEN  1610612743       f  L  30.0  52.0
# ...

# %%
#create entry for each game_id and use team name OR team id as team stat prefix

# %%
#df_teams[df_games_2014['team_id'] == df_teams['team_id']]['abbreviation']

#join df_games and df_teams on team_id

#df_games.join(df_teams[['team_id', 'abbreviation']], on='team_id', how='left')

df_games_2014 = pd.merge(df_games_2014df_games_2014 = , df_teams[['team_id', 'abbreviation']])
df_games_2014
# Out:
#        game_id  game_date      matchup     team_id is_home wl     w     l  \
# 0     21400027 2014-11-01    DAL @ NOP  1610612740       t  L   1.0   1.0
# 1     21400045 2014-11-03  MEM vs. NOP  1610612740       f  L   1.0   2.0
# 2     21400054 2014-11-04    CHA @ NOP  1610612740       t  W   2.0   2.0
# 3     21400089 2014-11-08  SAS vs. NOP  1610612740       f  W   3.0   2.0
# 4     21400098 2014-11-10  CLE vs. NOP  1610612740       f  L   3.0   3.0
# ...        ...        ...          ...         ...     ... ..   ...   ...
# 2403  21401157 2015-04-07  OKC vs. SAS  1610612759       f  W  52.0  26.0
# 2404  21401168 2015-04-08    HOU @ SAS  1610612759       t  W  53.0  26.0
# 2405  21401181 2015-04-10  HOU vs. SAS  1610612759       f  W  54.0  26.0
# 2406  21401200 2015-04-12    PHX @ SAS  1610612759       t  W  55.0  26.0
# 2407  21401223 2015-04-15  NOP vs. SAS  1610612759       f  L  55.0  27.0
#
#       w_pct  min   fgm   fga  fg_pct  fg3m  fg3a  fg3_pct   ftm   fta  ft_pct  \
# ...

# %%
df_games_2014[df_games_2014['team_id'] == 1610612759]
# Out:
#          game_id  game_date      matchup     team_id is_home wl     w     l  \
# 10653   21400064 2014-11-05    ATL @ SAS  1610612759       t  W   2.0   1.0
# 104811  21400069 2014-11-06  HOU vs. SAS  1610612759       f  L   2.0   2.0
# 104810  21400089 2014-11-08    NOP @ SAS  1610612759       t  L   2.0   3.0
# 10652   21400102 2014-11-10  LAC vs. SAS  1610612759       f  W   3.0   3.0
# 104809  21400108 2014-11-11  GSW vs. SAS  1610612759       f  W   4.0   3.0
# 10651   21400131 2014-11-14  LAL vs. SAS  1610612759       f  W   5.0   3.0
# 104808  21400139 2014-11-15  SAC vs. SAS  1610612759       f  L   5.0   4.0
# 10650   21400152 2014-11-17    PHI @ SAS  1610612759       t  W   6.0   4.0
# 104807  21400159 2014-11-19  CLE vs. SAS  1610612759       f  W   7.0   4.0
# 42302   21400177 2014-11-21  MIN vs. SAS  1610612759       f  W   8.0   4.0
# 73597   21400191 2014-11-22    BKN @ SAS  1610612759       t  W   9.0   4.0
# ...

# %%
plt.scatter(df_games_2014[df_games_2014['team_id'] == 1610612759]['game_date'], df_games_2014[df_games_2014['team_id'] == 1610612759]['w_pct'])

# %%
#<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<

# %%
for column in df_games_2014.columns:
    if(column != 'game_id' and column != 'game_date'):
        df_games_2014.rename()
        print(column)
# Out:
# matchup
# team_id
# is_home
# wl
# w
# l
# w_pct
# min
# fgm
# fga
# fg_pct
# fg3m
# fg3a
# fg3_pct
# ftm
# fta
# ft_pct
# oreb
# dreb
# reb
# ast
# stl
# blk
# tov
# pf
# pts
# a_team_id
# season_year
# season_type
# season

# %%
#make new dataframe with team abbreviation prefix for each stat


#something to build from here??????????????????????
pd.merge(df_games_2014, df_games_2014, on=['game_id', 'game_date'], how='outer', suffixes=['', '_r'])
# Out:
#        game_id  game_date      matchup     team_id is_home wl     w     l  \
# 0     21400027 2014-11-01    DAL @ NOP  1610612740       t  L   1.0   1.0
# 1     21400027 2014-11-01    DAL @ NOP  1610612740       t  L   1.0   1.0
# 2     21400027 2014-11-01  NOP vs. DAL  1610612742       f  W   2.0   1.0
# 3     21400027 2014-11-01  NOP vs. DAL  1610612742       f  W   2.0   1.0
# 4     21400028 2014-11-01    MEM @ CHA  1610612766       t  L   1.0   1.0
# ...        ...        ...          ...         ...     ... ..   ...   ...
# 4811  21401229 2015-04-15  GSW vs. DEN  1610612743       f  L  30.0  52.0
# 4812  21401230 2015-04-15  LAL vs. SAC  1610612758       f  W  29.0  53.0
# 4813  21401230 2015-04-15  LAL vs. SAC  1610612758       f  W  29.0  53.0
# 4814  21401230 2015-04-15    SAC @ LAL  1610612747       t  L  21.0  61.0
# 4815  21401230 2015-04-15    SAC @ LAL  1610612747       t  L  21.0  61.0
#
#       w_pct  min   fgm   fga  fg_pct  fg3m  fg3a  fg3_pct   ftm   fta  ft_pct  \
# ...

# %%
pd.merge(df_games_2014[df_games_2014['is_home'] == 't'],
         df_games_2014[df_games_2014['is_home'] == 'f'], on=['game_id', 'game_date'])
# Out:
#        game_id  game_date  matchup_x   team_id_x is_home_x wl_x   w_x   l_x  \
# 0     21400027 2014-11-01  DAL @ NOP  1610612740         t    L   1.0   1.0
# 1     21400028 2014-11-01  MEM @ CHA  1610612766         t    L   1.0   1.0
# 2     21400029 2014-11-01  TOR @ ORL  1610612753         t    L   0.0   3.0
# 3     21400030 2014-11-01  MIA @ PHI  1610612755         t    L   0.0   3.0
# 4     21400031 2014-11-01  MIL @ WAS  1610612764         t    W   2.0   1.0
# ...        ...        ...        ...         ...       ...  ...   ...   ...
# 1199  21401226 2015-04-15  DET @ NYK  1610612752         t    L  17.0  65.0
# 1200  21401227 2015-04-15  MIA @ PHI  1610612755         t    L  18.0  64.0
# 1201  21401228 2015-04-15  CHA @ TOR  1610612761         t    W  49.0  33.0
# 1202  21401229 2015-04-15  DEN @ GSW  1610612744         t    W  67.0  15.0
# 1203  21401230 2015-04-15  SAC @ LAL  1610612747         t    L  21.0  61.0
#
# ...

# %% [markdown]
# <font color='red'> how to get a column for each team per stat?????<font>

# %%
#big picture:
    #build columns that go with the (original) individual entries and then combine in later step????
    
#sub objective:
    
    #get unique game id's
    
    #initialize empty dataframe
    
    #loop through unique game id's
    
    #merge the visitor and home team columns AND give them suffixes per team abbreviation
    
    #merge with new dataframe by joining outer

# %%
#plt.scatter(df_games_date_clean['game_date'], df_games_date_clean['game_id'])

# %%
df_games_date_clean.set_index(['game_id', 'game_date'])
# Out:
#                          matchup     team_id is_home wl    w    l  w_pct  min  \
# game_id  game_date
# 11100001 2011-12-16  IND vs. CHI  1610612741       f  W  1.0  0.0    1.0  240
#          2011-12-16    CHI @ IND  1610612754       t  L  0.0  1.0    0.0  240
# 11100002 2011-12-16  MEM vs. NOH  1610612740       f  W  1.0  0.0    1.0  240
#          2011-12-16    NOH @ MEM  1610612763       t  L  0.0  1.0    0.0  240
# 11100003 2011-12-16    PHI @ WAS  1610612764       t  L  0.0  1.0    0.0  240
# ...                          ...         ...     ... ..  ...  ...    ...  ...
# 49900086 2000-06-14    LAL @ IND  1610612754       t  L  NaN  NaN    NaN  265
# 49900087 2000-06-16  IND vs. LAL  1610612747       f  L  NaN  NaN    NaN  240
#          2000-06-16    LAL @ IND  1610612754       t  W  NaN  NaN    NaN  240
# 49900088 2000-06-19    IND @ LAL  1610612747       t  W  NaN  NaN    NaN  240
#          2000-06-19  LAL vs. IND  1610612754       f  L  NaN  NaN    NaN  240
#
# ...

# %%
df_games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125624 entries, 0 to 125623
# Data columns (total 32 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   game_id      125624 non-null  int64
#  1   game_date    119376 non-null  object
#  2   matchup      125624 non-null  object
#  3   team_id      125624 non-null  int64
#  4   is_home      125624 non-null  object
#  5   wl           125614 non-null  object
#  6   w            41000 non-null   float64
#  7   l            41000 non-null   float64
#  8   w_pct        41000 non-null   float64
#  9   min          125624 non-null  int64
#  10  fgm          125607 non-null  float64
#  11  fga          90894 non-null   float64
#  12  fg_pct       90871 non-null   float64
#  13  fg3m         95248 non-null   float64
#  14  fg3a         84316 non-null   float64
#  15  fg3_pct      80062 non-null   float64
#  16  ftm          125605 non-null  float64
# ...

# %%
df_games['game_date'].unique()
# Out:
# array(['2009-02-06', '2009-01-31', '2009-01-16', ..., '2008-05-05',
#        '2008-01-20', '2008-05-27'], dtype=object)

# %%
df_games['game_date'].unique().shape
# Out:
# (11934,)

# %%
df_games[df_games['game_date'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [game_id, game_date, matchup, team_id, is_home, wl, w, l, w_pct, min, fgm, fga, fg_pct, fg3m, fg3a, fg3_pct, ftm, fta, ft_pct, oreb, dreb, reb, ast, stl, blk, tov, pf, pts, a_team_id, season_year, season_type, season]
# Index: []

# %%
df_games[df_games['game_date'] == np.nan]
# Out:
# Empty DataFrame
# Columns: [game_id, game_date, matchup, team_id, is_home, wl, w, l, w_pct, min, fgm, fga, fg_pct, fg3m, fg3a, fg3_pct, ftm, fta, ft_pct, oreb, dreb, reb, ast, stl, blk, tov, pf, pts, a_team_id, season_year, season_type, season]
# Index: []
