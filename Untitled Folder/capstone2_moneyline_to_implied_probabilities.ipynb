# %%
#calculation of implied probablity: 'price1_implied_prob', 'price2_implied_prob'

#how do we determine is the betting odds are over or under estimated?

#linear regression for match up???? 

#logistic regression for match up?

# %%
import pandas as pd
import numpy as np



pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
df = pd.read_csv('C:\\Users\\Paul\\sb\\Untitled Folder\\raw_data\\nba_betting_money_line.csv')
df.head()
# Out:
#     game_id        book_name  book_id     team_id   a_team_id  price1  price2
# 0  41100314  Pinnacle Sports      238  1610612759  1610612760   165.0  -183.0
# 1  41100314           5Dimes       19  1610612759  1610612760   165.0  -175.0
# 2  41100314        Bookmaker       93  1610612759  1610612760   160.0  -190.0
# 3  41100314        BetOnline     1096  1610612759  1610612760   165.0  -190.0
# 4  41100314           Bovada   999996  1610612759  1610612760   155.0  -175.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125286 entries, 0 to 125285
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   game_id    125286 non-null  int64
#  1   book_name  125286 non-null  object
#  2   book_id    125286 non-null  int64
#  3   team_id    125286 non-null  int64
#  4   a_team_id  125286 non-null  int64
#  5   price1     125286 non-null  float64
#  6   price2     125286 non-null  float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 6.7+ MB

# %%
df[['price1']]
# Out:
#         price1
# 0        165.0
# 1        165.0
# 2        160.0
# 3        165.0
# 4        155.0
# ...        ...
# 125281   105.0
# 125282   100.0
# 125283   105.0
# 125284   100.0
# 125285   105.0
#
# [125286 rows x 1 columns]

# %%
print(type(df[['price1']]))
print(type(df['price1']))
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# <font color='red'> does it matter which is saved as a new column of a dataframe?????</font>

# %%
df[df[['price1']] > 0].count()
# Out:
# game_id          0
# book_name        0
# book_id          0
# team_id          0
# a_team_id        0
# price1       83548
# price2           0
# dtype: int64

# %%
df[df[['price1']] > 0].head()
# Out:
#    game_id book_name  book_id  team_id  a_team_id  price1  price2
# 0      NaN       NaN      NaN      NaN        NaN   165.0     NaN
# 1      NaN       NaN      NaN      NaN        NaN   165.0     NaN
# 2      NaN       NaN      NaN      NaN        NaN   160.0     NaN
# 3      NaN       NaN      NaN      NaN        NaN   165.0     NaN
# 4      NaN       NaN      NaN      NaN        NaN   155.0     NaN

# %%
df[df['price1'] > 0]['price1'].head()
# Out:
# 0    165.0
# 1    165.0
# 2    160.0
# 3    165.0
# 4    155.0
# Name: price1, dtype: float64

# %%
type(df[df['price1'] > 0]['price1'])
# Out:
# pandas.core.series.Series

# %%
df[df['price1'] > 0]['price1'].count()
# Out:
# 83548

# %%
df[df['price1'] < 0]['price1'].count()
# Out:
# 41738

# %%
#negative price1
ml_neg = df[df['price1'] < 0]['price1']
ml_neg
# Out:
# 10       -128.0
# 11       -128.0
# 12       -135.0
# 13       -135.0
# 14       -119.0
#           ...
# 125271   -260.0
# 125272   -255.0
# 125273   -250.0
# 125274   -280.0
# 125275   -247.0
# Name: price1, Length: 41738, dtype: float64

# %%
favorite = (-1 * ml_neg) / (100 + (-1) * ml_neg)
favorite
# Out:
# 10        0.561404
# 11        0.561404
# 12        0.574468
# 13        0.574468
# 14        0.543379
#             ...
# 125271    0.722222
# 125272    0.718310
# 125273    0.714286
# 125274    0.736842
# 125275    0.711816
# Name: price1, Length: 41738, dtype: float64

# %%
#positive price1
ml_pos = df[df['price1'] > 0]['price1']
ml_pos
# Out:
# 0         165.0
# 1         165.0
# 2         160.0
# 3         165.0
# 4         155.0
#           ...
# 125281    105.0
# 125282    100.0
# 125283    105.0
# 125284    100.0
# 125285    105.0
# Name: price1, Length: 83548, dtype: float64

# %%
underdog = 100 / (ml_pos + 100)

# %%
print(type(favorite))
print(type(underdog))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>

# %%
#pd.merge(favorite, underdog).head(111)

# %%
dff = pd.concat([favorite, underdog], axis=0)

# %%
type(dff)
# Out:
# pandas.core.series.Series

# %%
dff.head(111)
# Out:
# 10     0.561404
# 11     0.561404
# 12     0.574468
# 13     0.574468
# 14     0.543379
# 15     0.565217
# 16     0.574468
# 17     0.565217
# 18     0.574468
# 39     0.733333
# 40     0.736842
# 41     0.753086
# 42     0.750000
# 43     0.750000
# 44     0.743590
# 45     0.750000
# 46     0.743590
# 47     0.740260
# 48     0.750000
# 69     0.722222
# 70     0.726027
# 71     0.733333
# 72     0.733333
# 73     0.733333
# 74     0.729730
# 75     0.718310
# 76     0.722222
# 77     0.726027
# 78     0.733333
# 79     0.530516
# 80     0.541284
# 81     0.555556
# 82     0.555556
# 83     0.555556
# 84     0.545455
# 85     0.555556
# 86     0.549550
# 87     0.555556
# 88     0.519231
# 89     0.526066
# 90     0.545455
# 91     0.545455
# 92     0.555556
# 93     0.545455
# 94     0.555556
# 95     0.545455
# 96     0.545455
# 107    0.514563
# 108    0.512195
# 109    0.523810
# 111    0.523810
# 112    0.523810
# 114    0.512195
# 154    0.588477
# 155    0.583333
# ...

# %%
#dff.iloc[:,0].count()

# %%
#dff.iloc[:,1].count()

# %%
dff = dff.sort_index()

# %%
dff
# Out:
# 0         0.377358
# 1         0.377358
# 2         0.384615
# 3         0.377358
# 4         0.392157
#             ...
# 125281    0.487805
# 125282    0.500000
# 125283    0.487805
# 125284    0.500000
# 125285    0.487805
# Name: price1, Length: 125286, dtype: float64

# %%
dff.head(111)
# Out:
# 0      0.377358
# 1      0.377358
# 2      0.384615
# 3      0.377358
# 4      0.392157
# 5      0.380228
# 6      0.377358
# 7      0.377358
# 8      0.377358
# 9      0.377358
# 10     0.561404
# 11     0.561404
# 12     0.574468
# 13     0.574468
# 14     0.543379
# 15     0.565217
# 16     0.574468
# 17     0.565217
# 18     0.574468
# 19     0.347222
# 20     0.344828
# 21     0.357143
# 22     0.344828
# 23     0.350877
# 24     0.350877
# 25     0.338983
# 26     0.338983
# 27     0.361011
# 28     0.344828
# 29     0.214133
# 30     0.210526
# 31     0.212766
# 32     0.217391
# 33     0.243902
# 34     0.215054
# 35     0.227273
# 36     0.219780
# 37     0.217391
# 38     0.217391
# 39     0.733333
# 40     0.736842
# 41     0.753086
# 42     0.750000
# 43     0.750000
# 44     0.743590
# 45     0.750000
# 46     0.743590
# 47     0.740260
# 48     0.750000
# 49     0.265252
# 50     0.259740
# 51     0.259740
# 52     0.263158
# 53     0.273973
# 54     0.266667
# ...

# %%
def american_odds_to_implied_prob(df_, col_):
    ml_neg = df_[df_[col_] < 0][col_]
    favorite = (-1 * ml_neg) / (100 + (-1) * ml_neg)
    
    ml_pos = df_[df_[col_] > 0][col_]
    underdog = 100 / (ml_pos + 100)
    
    df_ = pd.concat([favorite, underdog], axis=0)
    return df_.sort_index()

# %%
df['price1_implied_prob'] = american_odds_to_implied_prob(df, 'price1')
df.head(111)
# Out:
#       game_id        book_name  book_id     team_id   a_team_id  price1  \
# 0    41100314  Pinnacle Sports      238  1610612759  1610612760   165.0
# 1    41100314           5Dimes       19  1610612759  1610612760   165.0
# 2    41100314        Bookmaker       93  1610612759  1610612760   160.0
# 3    41100314        BetOnline     1096  1610612759  1610612760   165.0
# 4    41100314           Bovada   999996  1610612759  1610612760   155.0
# 5    41100314         Heritage      169  1610612759  1610612760   163.0
# 6    41100314        Intertops      180  1610612759  1610612760   165.0
# 7    41100314         YouWager      139  1610612759  1610612760   165.0
# 8    41100314          JustBet     1275  1610612759  1610612760   165.0
# 9    41100314    Sportsbetting   999991  1610612759  1610612760   165.0
# 10   41100304  Pinnacle Sports      238  1610612748  1610612738  -128.0
# 11   41100304           5Dimes       19  1610612748  1610612738  -128.0
# ...

# %%
df['price1_implied_prob'].value_counts().head(111)
# Out:
# 0.392157    1835
# 0.370370    1780
# 0.476190    1736
# 0.454545    1733
# 0.434783    1714
# 0.384615    1654
# 0.565217    1653
# 0.357143    1557
# 0.408163    1557
# 0.333333    1554
# 0.377358    1548
# 0.555556    1524
# 0.425532    1474
# 0.363636    1457
# 0.285714    1425
# 0.416667    1414
# 0.400000    1353
# 0.322581    1340
# 0.487805    1340
# 0.444444    1329
# 0.344828    1328
# 0.465116    1301
# 0.583333    1291
# 0.200000    1282
# 0.545455    1271
# 0.303030    1173
# 0.312500    1150
# 0.600000    1147
# 0.615385    1135
# 0.655172    1116
# 0.500000    1105
# 0.622642    1074
# 0.250000    1073
# 0.350877    1056
# 0.574468    1032
# 0.534884    1025
# 0.277778    1021
# 0.607843    1017
# 0.591837    1013
# 0.666667    1001
# 0.263158     977
# 0.256410     966
# 0.636364     962
# 0.294118     959
# 0.512195     944
# 0.222222     939
# 0.629630     927
# 0.270270     903
# 0.338983     876
# 0.677419     779
# 0.307692     774
# 0.327869     769
# ...

# %% [markdown]
# <font color='red'> considered rounding? and why???? <font>

# %%
df['price1_implied_prob'].hist(bins=111)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125286 entries, 0 to 125285
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   game_id              125286 non-null  int64
#  1   book_name            125286 non-null  object
#  2   book_id              125286 non-null  int64
#  3   team_id              125286 non-null  int64
#  4   a_team_id            125286 non-null  int64
#  5   price1               125286 non-null  float64
#  6   price2               125286 non-null  float64
#  7   price1_implied_prob  125286 non-null  float64
# dtypes: float64(3), int64(4), object(1)
# memory usage: 7.6+ MB

# %%
df['price2']
# Out:
# 0        -183.0
# 1        -175.0
# 2        -190.0
# 3        -190.0
# 4        -175.0
#           ...
# 125281   -125.0
# 125282   -120.0
# 125283   -125.0
# 125284   -120.0
# 125285   -125.0
# Name: price2, Length: 125286, dtype: float64

# %%
#df['price2_implied_prob'] = american_odds_to_implied_prob(df, 'price2')
american_odds_to_implied_prob(df, 'price2')
# Out:
# 0         0.646643
# 1         0.636364
# 2         0.655172
# 3         0.655172
# 4         0.636364
#             ...
# 125281    0.555556
# 125282    0.545455
# 125283    0.555556
# 125284    0.545455
# 125285    0.555556
# Name: price2, Length: 125286, dtype: float64

# %%
df['price2_implied_prob'] = american_odds_to_implied_prob(df, 'price2')

# %%
df_ = df
col_ = 'price2'
ml_neg = df_[df_[col_] < 0][col_]
favorite = (-1 * ml_neg) / (100 + (-1) * ml_neg)

ml_pos = df_[df_[col_] > 0][col_]
underdog = 100 / (ml_pos + 100)

df_ = pd.concat([favorite, underdog], axis=0)
df_.sort_index()
# Out:
# 0         0.646643
# 1         0.636364
# 2         0.655172
# 3         0.655172
# 4         0.636364
#             ...
# 125281    0.555556
# 125282    0.545455
# 125283    0.555556
# 125284    0.545455
# 125285    0.555556
# Name: price2, Length: 125286, dtype: float64

# %%
favorite.shape
# Out:
# (86575,)

# %%
underdog.shape
# Out:
# (38711,)

# %%
df.head(111)
# Out:
#       game_id        book_name  book_id     team_id   a_team_id  price1  \
# 0    41100314  Pinnacle Sports      238  1610612759  1610612760   165.0
# 1    41100314           5Dimes       19  1610612759  1610612760   165.0
# 2    41100314        Bookmaker       93  1610612759  1610612760   160.0
# 3    41100314        BetOnline     1096  1610612759  1610612760   165.0
# 4    41100314           Bovada   999996  1610612759  1610612760   155.0
# 5    41100314         Heritage      169  1610612759  1610612760   163.0
# 6    41100314        Intertops      180  1610612759  1610612760   165.0
# 7    41100314         YouWager      139  1610612759  1610612760   165.0
# 8    41100314          JustBet     1275  1610612759  1610612760   165.0
# 9    41100314    Sportsbetting   999991  1610612759  1610612760   165.0
# 10   41100304  Pinnacle Sports      238  1610612748  1610612738  -128.0
# 11   41100304           5Dimes       19  1610612748  1610612738  -128.0
# ...
