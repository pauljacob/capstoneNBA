# %%
#big picture:

    #predict the nba score for each team.----->scores to give insight into betting spreads

#sub-objective:

    #1. get nba visitor team score and home team score (2 columns)
    
    #2. subtract the home team score from the visitor team score (difference of two columns)
    
    #3. set game_id as index of difference (new index)
    
    #4. get game_id and spread1 (2 new columns)
    
    #5. set game_id as index (new index)
    
    #6. plot this difference against spread1 (plot the df's to one)

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# %%
df_spreads = pd.read_csv('C:\\Users\\Paul\\sb\\Untitled Folder\\raw_data\\nba_betting_spread.csv')
df_spreads.head()
# Out:
#     game_id        book_name  book_id     team_id   a_team_id  spread1  \
# 0  21000358  Pinnacle Sports      238  1610612749  1610612742      7.5
# 1  21000358           5Dimes       19  1610612749  1610612742      7.5
# 2  21000358        Bookmaker       93  1610612749  1610612742      7.5
# 3  21000358        BetOnline     1096  1610612749  1610612742      7.5
# 4  21000358           Bovada   999996  1610612749  1610612742      8.0
#
#    spread2  price1  price2
# 0     -7.5  -106.0  -104.0
# 1     -7.5  -110.0  -110.0
# 2     -7.5  -110.0  -110.0
# 3     -7.5  -110.0  -110.0
# 4     -8.0  -115.0  -105.0

# %%
df_games = pd.read_csv('C:\\Users\\Paul\\sb\\Untitled Folder\\raw_data\\nba_games_all.csv')
df_games.head()
# Out:
#     game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0  20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 1  20800701  2009-01-31  POR vs. UTA  1610612762       f  L  26.0  22.0
# 2  20800584  2009-01-16  MEM vs. UTA  1610612762       f  W  24.0  16.0
# 3  20800558  2009-01-12    IND @ UTA  1610612762       t  W  23.0  15.0
# 4  20800440  2008-12-27  HOU vs. UTA  1610612762       f  L  18.0  14.0
#
#    w_pct  min   fgm    fga  fg_pct  fg3m  fg3a  fg3_pct   ftm   fta  ft_pct  \
# 0  0.569  240  39.0   74.0   0.527   4.0  13.0    0.308  29.0  37.0     1.0
# 1  0.542  240  37.0   68.0   0.544   5.0  20.0    0.250  29.0  37.0     1.0
# 2  0.600  240  37.0   71.0   0.521   7.0  19.0    0.368  20.0  27.0     1.0
# 3  0.605  240  39.0   85.0   0.459   8.0  18.0    0.444  34.0  37.0     1.0
# 4  0.563  290  49.0  100.0   0.490   5.0  13.0    0.385  12.0  18.0     1.0
#
# ...

# %%
df_games.shape
# Out:
# (125624, 32)

# %%
######<<<<<<<<<<<<<<<<<<<<<########################<<<<<<<<<<<<<<<<<<<<<<<<<<#####################<<<<<<<<<<<<<<<<<<
#1. get nba visitor team score and home team score (2 columns)
df_games.game_id.unique()
# Out:
# array([20800741, 20800701, 20800584, ..., 20800839, 10800107, 20800810],
#       dtype=int64)

# %%
#df = pd.DataFrame({'game_id':df_games.game_id.unique()})
#df.head()

# %% [markdown]
# #scores
# visitor = np.array(df_games.game_id.unique().shape[0])
# home = np.array(df_games.game_id.unique().shape[0])
#
# #collect the scores
# for game_id_ in df_games.game_id.unique():
#
#     #get visitor and home team single game stats
#     df_games[df_games['game_id'] == game_id_]
#
#     home = home + (df_games[df_games['game_id'] == game_id_][df_games['is_home'] == 't'][['game_id','pts']])
#
#     visitor = visitor + (df_games[df_games['game_id'] == game_id_][df_games['is_home'] == 'f'][['game_id','pts']])

# %%
#visitor.shape

# %%
#columns of interest in df_games are ['game_id', 'is_home', 'pts']

df_games[['game_id', 'is_home', 'pts']]

#df_games_home = df_games[['game_id', 'is_home', 'pts']][df_games['is_home'] == 't']
df_games_home = df_games[['game_id', 'pts']][df_games['is_home'] == 't'].rename(columns={'pts':'pts_home'})
df_games_home
# Out:
#          game_id  pts_home
# 3       20800558       120
# 6       29800603        91
# 7       29800577        98
# 8       29800561        87
# 9       20800344        94
# ...          ...       ...
# 125617  10800107        87
# 125619  20801131       102
# 125620  20801058        99
# 125622  20800839       108
# 125623  20800810        90
#
# [62812 rows x 2 columns]

# %%
#df_games_not_home = df_games[['game_id', 'is_home', 'pts']][df_games['is_home'] == 'f']
df_games_not_home = df_games[['game_id', 'pts']][df_games['is_home'] == 'f'].rename(columns={'pts':'pts_not_home'})
df_games_not_home
# Out:
#          game_id  pts_not_home
# 0       20800741           111
# 1       20800701           108
# 2       20800584           101
# 4       20800440           115
# 5       20800395            98
# ...          ...           ...
# 125613  20800441            87
# 125614  20800052           100
# 125615  20800042           101
# 125618  10800025            73
# 125621  20801029           101
#
# [62812 rows x 2 columns]

# %%
df_games_pts = df_games_not_home.merge(df_games_home)
df_games_pts
# Out:
#         game_id  pts_not_home  pts_home
# 0      20800741           111       107
# 1      20800701           108       122
# 2      20800584           101        91
# 3      20800440           115       120
# 4      20800395            98       106
# ...         ...           ...       ...
# 62807  20800441            87        76
# 62808  20800052           100        93
# 62809  20800042           101        83
# 62810  10800025            73        62
# 62811  20801029           101        94
#
# [62812 rows x 3 columns]

# %%
#actual point difference by game_id
df_games_pts['pts_diff'] = - (df_games_pts['pts_not_home'] - df_games_pts['pts_home'])
df_games_pts
# Out:
#         game_id  pts_not_home  pts_home  pts_diff
# 0      20800741           111       107        -4
# 1      20800701           108       122        14
# 2      20800584           101        91       -10
# 3      20800440           115       120         5
# 4      20800395            98       106         8
# ...         ...           ...       ...       ...
# 62807  20800441            87        76       -11
# 62808  20800052           100        93        -7
# 62809  20800042           101        83       -18
# 62810  10800025            73        62       -11
# 62811  20801029           101        94        -7
#
# [62812 rows x 4 columns]

# %%
#get unique game_id

#get unique game_id count

#get book_name uniques

#get counts by book_name

#compare them

# %%
df_spreads['game_id']
# Out:
# 0         21000358
# 1         21000358
# 2         21000358
# 3         21000358
# 4         21000358
#             ...
# 131685    21501153
# 131686    21501153
# 131687    21501153
# 131688    21501153
# 131689    21501153
# Name: game_id, Length: 131690, dtype: int64

# %%
df_spreads['game_id'].unique()
# Out:
# array([21000358, 21000361, 21000362, ..., 21501150, 21501151, 21501152],
#       dtype=int64)

# %%
df_spreads['game_id'].unique().shape
# Out:
# (14914,)

# %%
df_spreads['book_name'].unique()
# Out:
# array(['Pinnacle Sports', '5Dimes', 'Bookmaker', 'BetOnline', 'Bovada',
#        'Intertops', 'YouWager', 'JustBet', 'Sportsbetting', 'Heritage'],
#       dtype=object)

# %%
df_spreads['book_name'].unique().shape
# Out:
# (10,)

# %%
df_spreads['book_name'].value_counts()
# Out:
# 5Dimes             14904
# Bovada             14897
# Pinnacle Sports    14894
# Bookmaker          14867
# BetOnline          13789
# Sportsbetting      13789
# JustBet            13687
# Intertops          12214
# YouWager            9942
# Heritage            8707
# Name: book_name, dtype: int64

# %%
#5Dimes as an example
df_spreads[df_spreads['book_name'] == '5Dimes']
# Out:
#          game_id book_name  book_id     team_id   a_team_id  spread1  spread2  \
# 1       21000358    5Dimes       19  1610612749  1610612742      7.5     -7.5
# 10      21000361    5Dimes       19  1610612755  1610612751     -1.5      1.5
# 19      21000362    5Dimes       19  1610612747  1610612764    -10.0     10.0
# 28      21000367    5Dimes       19  1610612747  1610612754     -3.5      3.5
# 37      21000372    5Dimes       19  1610612766  1610612763      8.5     -8.5
# ...          ...       ...      ...         ...         ...      ...      ...
# 131643  21501139    5Dimes       19  1610612765  1610612741      3.0     -3.0
# 131653  21501150    5Dimes       19  1610612741  1610612749      1.5     -1.5
# 131663  21501151    5Dimes       19  1610612754  1610612752     -7.0      7.0
# 131673  21501152    5Dimes       19  1610612757  1610612744     11.5    -11.5
# 131683  21501153    5Dimes       19  1610612738  1610612747     -9.5      9.5
#
#         price1  price2
# ...

# %%
df_spread1 = df_spreads[df_spreads['book_name'] == '5Dimes'][['game_id', 'spread1']]
df_spread1
# Out:
#          game_id  spread1
# 1       21000358      7.5
# 10      21000361     -1.5
# 19      21000362    -10.0
# 28      21000367     -3.5
# 37      21000372      8.5
# ...          ...      ...
# 131643  21501139      3.0
# 131653  21501150      1.5
# 131663  21501151     -7.0
# 131673  21501152     11.5
# 131683  21501153     -9.5
#
# [14904 rows x 2 columns]

# %%
df_games_pts.head(11)
# Out:
#      game_id  pts_not_home  pts_home  pts_diff
# 0   20800741           111       107        -4
# 1   20800701           108       122        14
# 2   20800584           101        91       -10
# 3   20800440           115       120         5
# 4   20800395            98       106         8
# 5   20801103           114       109        -5
# 6   20801090            66        86        20
# 7   20800796            99       117        18
# 8   49800035            75        87        12
# 9   49800004            70        90        20
# 10  29800681            91        78       -13

# %%
df_games_pts_diff = df_games_pts[['game_id','pts_diff']]
df_games_pts_diff.head(11)
# Out:
#      game_id  pts_diff
# 0   20800741        -4
# 1   20800701        14
# 2   20800584       -10
# 3   20800440         5
# 4   20800395         8
# 5   20801103        -5
# 6   20801090        20
# 7   20800796        18
# 8   49800035        12
# 9   49800004        20
# 10  29800681       -13

# %%
df_games_pts_diff.shape
# Out:
# (62812, 2)

# %%
df_spread1.head(11)
# Out:
#      game_id  spread1
# 1   21000358      7.5
# 10  21000361     -1.5
# 19  21000362    -10.0
# 28  21000367     -3.5
# 37  21000372      8.5
# 46  21000376     10.0
# 55  21000378      6.0
# 64  21000384      5.5
# 73  21000382     -5.0
# 82  21000385      7.0
# 91  21000419      3.0

# %%
df_spread1.shape
# Out:
# (14904, 2)

# %%
#5. set game_id as index (new index)

df_spread1.set_index('game_id', inplace=True)
df_spread1
# Out:
#           spread1
# game_id
# 21000358      7.5
# 21000361     -1.5
# 21000362    -10.0
# 21000367     -3.5
# 21000372      8.5
# ...           ...
# 21501139      3.0
# 21501150      1.5
# 21501151     -7.0
# 21501152     11.5
# 21501153     -9.5
#
# [14904 rows x 1 columns]

# %%
df_games_pts_diff.set_index('game_id', inplace=True)
df_games_pts_diff
# Out:
#           pts_diff
# game_id
# 20800741        -4
# 20800701        14
# 20800584       -10
# 20800440         5
# 20800395         8
# ...            ...
# 20800441       -11
# 20800052        -7
# 20800042       -18
# 10800025       -11
# 20801029        -7
#
# [62812 rows x 1 columns]

# %%
###############<<<<<<<<<<<<<#<<<<<<<<<<<<############<<<<<<<<<<<

df_spread1_pts_diff = df_spread1.join(df_games_pts_diff, how='inner')

# %%
plt.scatter(df_spread1_pts_diff['pts_diff'], df_spread1_pts_diff['spread1'])

plt.ylabel = 'pts_diff'
plt.xlabel = 'spread1'
plt.show()

# %%
from sklearn import linear_model

#plt.plot(df_spread1_pts_diff['spread1'], df_spread1_pts_diff['pts_diff'], color='blue', linewidth=3)

m, b = np.polyfit(df_spread1_pts_diff['pts_diff'], df_spread1_pts_diff['spread1'], 1)

plt.plot(df_spread1_pts_diff['pts_diff'], m * df_spread1_pts_diff['pts_diff'] + b)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

import statsmodels.api as sm

X = sm.add_constant(df_spread1_pts_diff['pts_diff'])

lm = LinearRegression()
lm.fit(X, df_spread1_pts_diff['spread1'])

lm.score(X, df_spread1_pts_diff['spread1'])

#pts_predicted = lm.predict(df_spread1_pts_diff['pts_diff'])


#r2_score(df_spread1_pts_diff['pts_diff'], pts_predicted)
# Out:
# 0.21247401266363597

# %%
#import seaborn as sns
#sns.pairplot()

# %%
df_spread1_pts_diff['visitor_win'] = df_spread1_pts_diff['pts_diff'] < df_spread1_pts_diff['spread1']
df_spread1_pts_diff
# Out:
#           spread1  pts_diff  visitor_win
# game_id
# 21000358      7.5        -4         True
# 21000361     -1.5        -5         True
# 21000362    -10.0       -14         True
# 21000367     -3.5       -15         True
# 21000372      8.5        33        False
# ...           ...       ...          ...
# 21501139      3.0        -4         True
# 21501150      1.5        -4         True
# 21501151     -7.0        -5        False
# 21501152     11.5        25        False
# 21501153     -9.5        -7        False
#
# [14904 rows x 3 columns]

# %%
df_spread1_pts_diff['visitor_win'].value_counts()
# Out:
# True     7455
# False    7449
# Name: visitor_win, dtype: int64

# %% [markdown]
# <font color='red'> regardless of a bet on the home or visitor team, the outcome is a coin flip????????? -no <font>

# %%
df_spread1_pts_diff['home_win'] = df_spread1_pts_diff['pts_diff'] > df_spread1_pts_diff['spread1']
df_spread1_pts_diff
# Out:
#           spread1  pts_diff  visitor_win  home_win
# game_id
# 21000358      7.5        -4         True     False
# 21000361     -1.5        -5         True     False
# 21000362    -10.0       -14         True     False
# 21000367     -3.5       -15         True     False
# 21000372      8.5        33        False      True
# ...           ...       ...          ...       ...
# 21501139      3.0        -4         True     False
# 21501150      1.5        -4         True     False
# 21501151     -7.0        -5        False      True
# 21501152     11.5        25        False      True
# 21501153     -9.5        -7        False      True
#
# [14904 rows x 4 columns]

# %%
df_spread1_pts_diff['home_win'].value_counts()
# Out:
# False    7715
# True     7189
# Name: home_win, dtype: int64

# %% [markdown]
# <font color='red'> there is a slight biased against the home team winning???<font>

# %%
df_spread1_pts_diff['push'] = df_spread1_pts_diff['pts_diff'] == df_spread1_pts_diff['spread1']
df_spread1_pts_diff
# Out:
#           spread1  pts_diff  visitor_win  home_win   push
# game_id
# 21000358      7.5        -4         True     False  False
# 21000361     -1.5        -5         True     False  False
# 21000362    -10.0       -14         True     False  False
# 21000367     -3.5       -15         True     False  False
# 21000372      8.5        33        False      True  False
# ...           ...       ...          ...       ...    ...
# 21501139      3.0        -4         True     False  False
# 21501150      1.5        -4         True     False  False
# 21501151     -7.0        -5        False      True  False
# 21501152     11.5        25        False      True  False
# 21501153     -9.5        -7        False      True  False
#
# [14904 rows x 5 columns]

# %%
df_spread1_pts_diff['push'].value_counts()
# Out:
# False    14644
# True       260
# Name: push, dtype: int64

# %%
#260 push
#7189 home_win
#7455 visitor_win

# %%
7455 + 7189 + 260
# Out:
# 14904
