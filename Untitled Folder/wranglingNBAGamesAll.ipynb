# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.options.display.max_columns = 999
pd.options.display.max_rows = 999

# %%
df = pd.read_csv('nba_games_all.csv')

# %%
df.head(111)
# Out:
#       game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0    20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 1    20800701  2009-01-31  POR vs. UTA  1610612762       f  L  26.0  22.0
# 2    20800584  2009-01-16  MEM vs. UTA  1610612762       f  W  24.0  16.0
# 3    20800558  2009-01-12    IND @ UTA  1610612762       t  W  23.0  15.0
# 4    20800440  2008-12-27  HOU vs. UTA  1610612762       f  L  18.0  14.0
# 5    20800395  2008-12-20  CHI vs. UTA  1610612762       f  L  17.0  12.0
# 6    29800603  1999-04-21    TOR @ WAS  1610612764       t  L   NaN   NaN
# 7    29800577  1999-04-18    BOS @ WAS  1610612764       t  L   NaN   NaN
# 8    29800561  1999-04-16    CHI @ WAS  1610612764       t  W   NaN   NaN
# 9    20800344  2008-12-13    ORL @ UTA  1610612762       t  L  15.0  10.0
# 10   20800325  2008-12-11    POR @ UTA  1610612762       t  W  15.0   9.0
# 11   20801116  2009-04-01    WAS @ MEM  1610612763       t  W  20.0  54.0
# ...

# %%
df.team_id.unique().size
# Out:
# 57

# %%
#why are there 57 unique team_id's?

# %%
#how does the 57 unique team id's compare to the number of team id's in ???

# %%
df[df['game_id'] == 20800741]
# Out:
#       game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0    20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 233  20800741  2009-02-06    UTA @ SAC  1610612758       t  L  11.0  40.0
#
#      w_pct  min   fgm   fga  fg_pct  fg3m  fg3a  fg3_pct   ftm   fta  ft_pct  \
# 0    0.569  240  39.0  74.0   0.527   4.0  13.0    0.308  29.0  37.0     1.0
# 233  0.216  240  36.0  83.0   0.434   7.0  24.0    0.292  28.0  39.0     1.0
#
#      oreb  dreb  reb   ast   stl  blk   tov    pf  pts   a_team_id  \
# 0     8.0  36.0   44  19.0   5.0  4.0  18.0  26.0  111  1610612758
# 233  14.0  30.0   44  24.0  11.0  6.0  12.0  30.0  107  1610612762
#
#      season_year     season_type   season
# 0           2008  Regular Season  2008-09
# 233         2008  Regular Season  2008-09

# %%
df.groupby('season_year')

# %%
#for each season year how many games does each team id have?

# %%
ndarray = df['season_year'].unique()
ndarray
# Out:
# array([2008, 1998, 1950, 2007, 1999, 1997, 2009, 2016, 2000, 2010, 2001,
#        2011, 2002, 2012, 2003, 2013, 2006, 2004, 2014, 2005, 1973, 2017,
#        2015, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1974, 1975, 1985, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1984, 1996, 1994,
#        1995, 1986, 2018], dtype=int64)

# %%
type(ndarray)
# Out:
# numpy.ndarray

# %%
ndarray.sort()
ndarray
# Out:
# array([1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960,
#        1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
#        1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004,
#        2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015,
#        2016, 2017, 2018], dtype=int64)

# %%
df['team_id'].unique()
# Out:
# array([1610612762, 1610612764, 1610612763, 1610612765, 1610612766,
#        1610612760, 1610612761, 1610612753, 1610612751, 1610612754,
#        1610612752, 1610610036, 1610612758, 1610612756, 1610612755,
#        1610612757, 1610612750, 1610612743, 1610612741, 1610612746,
#        1610612747, 1610612745, 1610612748, 1610612749, 1610612759,
#        1610612739, 1610612737, 1610612742, 1610612738, 1610612740,
#        1610612744,      12304,         93,      12308, 1610610030,
#        1610610024, 1610616833,      12303,      12313,      12315,
#             12320,         94, 1610616834,      12325,      15016,
#             15015,      12316,      12323,      12329,      12306,
#                45,      12321,         41,      15018,      15017,
#             12324,      12330], dtype=int64)

# %%
df['season'].unique()
# Out:
# array(['2008-09', '1998-99', '1950-51', '2007-08', '1999-00', '1997-98',
#        '2009-10', '2016-17', '2000-01', '2010-11', '2001-02', '2011-12',
#        '2002-03', '2012-13', '2003-04', '2013-14', '2006-07', '2004-05',
#        '2014-15', '2005-06', '1973-74', '2017-18', '2015-16', '1951-52',
#        '1952-53', '1953-54', '1954-55', '1955-56', '1956-57', '1957-58',
#        '1958-59', '1959-60', '1960-61', '1961-62', '1962-63', '1963-64',
#        '1964-65', '1965-66', '1966-67', '1967-68', '1968-69', '1969-70',
#        '1970-71', '1971-72', '1972-73', '1974-75', '1975-76', '1985-86',
#        '1976-77', '1977-78', '1978-79', '1979-80', '1980-81', '1981-82',
#        '1982-83', '1983-84', '1987-88', '1988-89', '1989-90', '1990-91',
#        '1991-92', '1992-93', '1993-94', '1984-85', '1996-97', '1994-95',
#        '1995-96', '1986-87', '2018-19'], dtype=object)

# %%
df['season'].hist(bins=555)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(1, 2, figsize=(24,16))

df.season.value_counts().plot(kind='barh', ax=ax[0])

ax[0].set_title('Season')

ax[0].set_xlabel('Count')

df.season.value_counts().plot(kind='barh', ax=ax[1])

ax[1].set_title('Season')

ax[1].set_xlabel('Count')

plt.subplots_adjust(wspace=0.5);

# %%
#

# %%
df[df['season_year'] == 1998][['season_year','team_id']].count()
# Out:
# season_year    1582
# team_id        1582
# dtype: int64

# %%
dictionary = {}
for i in df['season_year'].unique():
    #print(i)
    dictionary.update({i:df[df['season_year'] == i].count().max()})

# %%
dictionary
# Out:
# {2008: 2860,
#  1998: 1582,
#  1950: 762,
#  2007: 2840,
#  1999: 2530,
#  1997: 2522,
#  2009: 2860,
#  2016: 2824,
#  2000: 2522,
#  2010: 2860,
#  2001: 2522,
#  2011: 2210,
#  2002: 2556,
#  2012: 2860,
#  2003: 2544,
#  2013: 2870,
#  2006: 2856,
#  2004: 2630,
#  2014: 2860,
#  2005: 2846,
#  1973: 1478,
#  2017: 2782,
#  2015: 2848,
#  1951: 712,
#  1952: 750,
#  1953: 694,
#  1954: 620,
#  1955: 624,
#  1956: 616,
#  1957: 620,
#  1958: 622,
#  1959: 652,
#  1960: 684,
#  1961: 780,
#  1962: 780,
#  1963: 776,
#  1964: 774,
#  1965: 776,
#  1966: 874,
#  1967: 1066,
#  1968: 1228,
#  1969: 1230,
#  1970: 1476,
#  1971: 1470,
#  1972: 1478,
#  1974: 1572,
#  1975: 1578,
#  1985: 2024,
#  1976: 1912,
#  1977: 1908,
#  1978: 1912,
#  1979: 1902,
#  1980: 1994,
#  1981: 1982,
#  1982: 1974,
#  1983: 2046,
#  1987: 2048,
#  1988: 2176,
#  1989: 2360,
#  1990: 2352,
#  1991: 2362,
#  1992: 2368,
#  1993: 2370,
#  1984: 2024,
#  1996: 2524,
#  1994: 2362,
#  1995: 2516,
# ...

# %%
import collections

# %%
odictionary = collections.OrderedDict(sorted(dictionary.items()))
odictionary
# Out:
# OrderedDict([(1950, 762),
#              (1951, 712),
#              (1952, 750),
#              (1953, 694),
#              (1954, 620),
#              (1955, 624),
#              (1956, 616),
#              (1957, 620),
#              (1958, 622),
#              (1959, 652),
#              (1960, 684),
#              (1961, 780),
#              (1962, 780),
#              (1963, 776),
#              (1964, 774),
#              (1965, 776),
#              (1966, 874),
#              (1967, 1066),
#              (1968, 1228),
#              (1969, 1230),
#              (1970, 1476),
#              (1971, 1470),
#              (1972, 1478),
#              (1973, 1478),
#              (1974, 1572),
#              (1975, 1578),
#              (1976, 1912),
#              (1977, 1908),
#              (1978, 1912),
#              (1979, 1902),
#              (1980, 1994),
#              (1981, 1982),
#              (1982, 1974),
#              (1983, 2046),
#              (1984, 2024),
# ...

# %% [markdown]
# #### pd.DataFrame.from_dict(dictionary)

# %%
df2
# Out:
# array([20800741, 20800701, 20800584, ..., 20800839, 10800107, 20800810],
#       dtype=int64)

# %%
#for i in df['season_year'].unique()
fig, ax = plt.subplots(1, 2, figsize=(24,16))

#df.season_year.value_counts().plot(kind='barh', ax=ax[0])
df[['season_year', 'team_id']].value_counts().plot(kind='barh', ax=ax[0])

ax[0].set_title('Season Year')

ax[0].set_xlabel('Count')



df.season_year.value_counts().plot(kind='barh', ax=ax[1])

ax[1].set_title('Season')

ax[1].set_xlabel('Count')

plt.subplots_adjust(wspace=0.5);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125624 entries, 0 to 125623
# Data columns (total 32 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   game_id      125624 non-null  int64
#  1   game_date    119376 non-null  object
#  2   matchup      125624 non-null  object
#  3   team_id      125624 non-null  int64
#  4   is_home      125624 non-null  object
#  5   wl           125614 non-null  object
#  6   w            41000 non-null   float64
#  7   l            41000 non-null   float64
#  8   w_pct        41000 non-null   float64
#  9   min          125624 non-null  int64
#  10  fgm          125607 non-null  float64
#  11  fga          90894 non-null   float64
#  12  fg_pct       90871 non-null   float64
#  13  fg3m         95248 non-null   float64
#  14  fg3a         84316 non-null   float64
#  15  fg3_pct      80062 non-null   float64
#  16  ftm          125605 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# game_id            0
# game_date       6248
# matchup            0
# team_id            0
# is_home            0
# wl                10
# w              84624
# l              84624
# w_pct          84624
# min                0
# fgm               17
# fga            34730
# fg_pct         34753
# fg3m           30376
# fg3a           41308
# fg3_pct        45562
# ftm               19
# fta             5613
# ft_pct          5664
# oreb           41838
# dreb           41985
# reb                0
# ast            35556
# stl            41664
# blk            41217
# tov            41331
# pf              3882
# pts                0
# a_team_id          0
# season_year        0
# season_type        0
# season             0
# dtype: int64

# %%
df2 = df['game_id'].unique()
df2
# Out:
# array([20800741, 20800701, 20800584, ..., 20800839, 10800107, 20800810],
#       dtype=int64)

# %%
df2.size
# Out:
# 62812

# %%
125624 / df2.size
# Out:
# 2.0

# %%
#how is it that exactly 1/2 of the total number of game id's is the number of unique ids?? -ok

# %%
df[df['game_id'] == 20800741]
# Out:
#       game_id   game_date      matchup     team_id is_home wl     w     l  \
# 0    20800741  2009-02-06  SAC vs. UTA  1610612762       f  W  29.0  22.0
# 233  20800741  2009-02-06    UTA @ SAC  1610612758       t  L  11.0  40.0
#
#      w_pct  min   fgm   fga  fg_pct  fg3m  fg3a  fg3_pct   ftm   fta  ft_pct  \
# 0    0.569  240  39.0  74.0   0.527   4.0  13.0    0.308  29.0  37.0     1.0
# 233  0.216  240  36.0  83.0   0.434   7.0  24.0    0.292  28.0  39.0     1.0
#
#      oreb  dreb  reb   ast   stl  blk   tov    pf  pts   a_team_id  \
# 0     8.0  36.0   44  19.0   5.0  4.0  18.0  26.0  111  1610612758
# 233  14.0  30.0   44  24.0  11.0  6.0  12.0  30.0  107  1610612762
#
#      season_year     season_type   season
# 0           2008  Regular Season  2008-09
# 233         2008  Regular Season  2008-09
